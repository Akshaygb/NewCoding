# %%
## Assignment 1

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### a) Read Movie Dataset Print head() & tail()

# %%
ds=pd.read_csv("movies_metadata.csv")
# Out:
# C:\Users\91720\AppData\Local\Temp\ipykernel_9496\4081790606.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   ds=pd.read_csv("movies_metadata.csv")

# %%
ds
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                         [{'id': 35, 'name': 'Comedy'}]
# ...                                                  ...
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                      [{'id': 18, 'name': 'Drama'}]
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                 []
# 45465                                                 []
#
#                                    homepage      id    imdb_id  \
# 0      http://toystory.disney.com/toy-story     862  tt0114709
# 1                                       NaN    8844  tt0113497
# 2                                       NaN   15602  tt0113228
# 3                                       NaN   31357  tt0114885
# 4                                       NaN   11862  tt0113041
# ...                                     ...     ...        ...
# 45461  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45462                                   NaN  111109  tt2028550
# 45463                                   NaN   67758  tt0303758
# 45464                                   NaN  227506  tt0008536
# 45465                                   NaN  461257  tt6980792
#
#       original_language               original_title  \
# 0                    en                    Toy Story
# 1                    en                      Jumanji
# 2                    en             Grumpier Old Men
# 3                    en            Waiting to Exhale
# 4                    en  Father of the Bride Part II
# ...                 ...                          ...
# 45461                fa                      رگ خواب
# 45462                tl          Siglo ng Pagluluwal
# 45463                en                     Betrayal
# 45464                en          Satana likuyushchiy
# 45465                en                     Queerama
#
#                                                 overview  ... release_date  \
# 0      Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1      When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2      A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3      Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4      Just when George Banks has recovered from his ...  ...   1995-02-10
# ...                                                  ...  ...          ...
# 45461        Rising and falling between a man and woman.  ...          NaN
# 45462  An artist struggles to finish his work while a...  ...   2011-11-17
# 45463  When one of her hits goes wrong, a professiona...  ...   2003-08-01
# 45464  In a small town live two brothers, one a minis...  ...   1917-10-21
# 45465  50 years after decriminalisation of homosexual...  ...   2017-06-09
#
#            revenue runtime                                   spoken_languages  \
# 0      373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1      262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2              0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4       76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# ...            ...     ...                                                ...
# 45461          0.0    90.0             [{'iso_639_1': 'fa', 'name': 'فارسی'}]
# 45462          0.0   360.0                  [{'iso_639_1': 'tl', 'name': ''}]
# 45463          0.0    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 45464          0.0    87.0                                                 []
# 45465          0.0    75.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 0      Released                                                NaN
# 1      Released          Roll the dice and unleash the excitement!
# 2      Released  Still Yelling. Still Fighting. Still Ready for...
# 3      Released  Friends are the people who let you be yourself...
# 4      Released  Just When His World Is Back To Normal... He's ...
# ...         ...                                                ...
# 45461  Released         Rising and falling between a man and woman
# 45462  Released                                                NaN
# 45463  Released                             A deadly game of wits.
# 45464  Released                                                NaN
# 45465  Released                                                NaN
#
#                              title  video vote_average vote_count
# 0                        Toy Story  False          7.7     5415.0
# 1                          Jumanji  False          6.9     2413.0
# 2                 Grumpier Old Men  False          6.5       92.0
# 3                Waiting to Exhale  False          6.1       34.0
# 4      Father of the Bride Part II  False          5.7      173.0
# ...                            ...    ...          ...        ...
# 45461                       Subdue  False          4.0        1.0
# 45462          Century of Birthing  False          9.0        3.0
# 45463                     Betrayal  False          3.8        6.0
# 45464             Satan Triumphant  False          0.0        0.0
# 45465                     Queerama  False          0.0        0.0
#
# [45466 rows x 24 columns]

# %%
ds.head() hey nina pakka yar kuntidare dont speak to girls kkkkk k le miss u nanu iratide alle ella nine hogu andee mich you alu nimmajji now work madbeku matte enuuuuu en madabeku vc madatini now
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
ds.tail()
# Out:
#        adult belongs_to_collection budget  \
# 45461  False                   NaN      0
# 45462  False                   NaN      0
# 45463  False                   NaN      0
# 45464  False                   NaN      0
# 45465  False                   NaN      0
#
#                                                   genres  \
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                      [{'id': 18, 'name': 'Drama'}]
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                 []
# 45465                                                 []
#
#                                    homepage      id    imdb_id  \
# 45461  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45462                                   NaN  111109  tt2028550
# 45463                                   NaN   67758  tt0303758
# 45464                                   NaN  227506  tt0008536
# 45465                                   NaN  461257  tt6980792
#
#       original_language       original_title  \
# 45461                fa              رگ خواب
# 45462                tl  Siglo ng Pagluluwal
# 45463                en             Betrayal
# 45464                en  Satana likuyushchiy
# 45465                en             Queerama
#
#                                                 overview  ... release_date  \
# 45461        Rising and falling between a man and woman.  ...          NaN
# 45462  An artist struggles to finish his work while a...  ...   2011-11-17
# 45463  When one of her hits goes wrong, a professiona...  ...   2003-08-01
# 45464  In a small town live two brothers, one a minis...  ...   1917-10-21
# 45465  50 years after decriminalisation of homosexual...  ...   2017-06-09
#
#       revenue runtime                          spoken_languages    status  \
# 45461     0.0    90.0    [{'iso_639_1': 'fa', 'name': 'فارسی'}]  Released
# 45462     0.0   360.0         [{'iso_639_1': 'tl', 'name': ''}]  Released
# 45463     0.0    90.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45464     0.0    87.0                                        []  Released
# 45465     0.0    75.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                           tagline                title  video  \
# 45461  Rising and falling between a man and woman               Subdue  False
# 45462                                         NaN  Century of Birthing  False
# 45463                      A deadly game of wits.             Betrayal  False
# 45464                                         NaN     Satan Triumphant  False
# 45465                                         NaN             Queerama  False
#
#       vote_average vote_count
# 45461          4.0        1.0
# 45462          9.0        3.0
# 45463          3.8        6.0
# 45464          0.0        0.0
# 45465          0.0        0.0
#
# [5 rows x 24 columns]

# %% [markdown]
# ### b) Print overall satistics of the data frame

# %%
ds.describe() wait
# Out:
#             revenue       runtime  vote_average    vote_count
# count  4.546000e+04  45203.000000  45460.000000  45460.000000
# mean   1.120935e+07     94.128199      5.618207    109.897338
# std    6.433225e+07     38.407810      1.924216    491.310374
# min    0.000000e+00      0.000000      0.000000      0.000000
# 25%    0.000000e+00     85.000000      5.000000      3.000000
# 50%    0.000000e+00     95.000000      6.000000     10.000000
# 75%    0.000000e+00    107.000000      6.800000     34.000000
# max    2.787965e+09   1256.000000     10.000000  14075.000000

# %% [markdown]
# ### c) Print data types of all the attributes

# %%
ds.dtypes
# Out:
# adult                     object
# belongs_to_collection     object
# budget                    object
# genres                    object
# homepage                  object
# id                        object
# imdb_id                   object
# original_language         object
# original_title            object
# overview                  object
# popularity                object
# poster_path               object
# production_companies      object
# production_countries      object
# release_date              object
# revenue                  float64
# runtime                  float64
# spoken_languages          object
# status                    object
# tagline                   object
# title                     object
# video                     object
# vote_average             float64
# vote_count               float64
# dtype: object

# %% [markdown]
# ### d) Check whether dataframe contains null values or not

# %%
ds.isnull().values.any() wait no i cant wait u send me pic
# Out:
# True

# %% [markdown]
# ### e) Count null values of all the columns

# %%
ds.isnull().sum()
# Out:
# adult                        0
# belongs_to_collection    40972
# budget                       0
# genres                       0
# homepage                 37684
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25054
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %% [markdown]
# ### f) Replace all the null values of the dataframe with true or false

# %%
ds.isnull()
# Out:
#        adult  belongs_to_collection  budget  genres  homepage     id  imdb_id  \
# 0      False                  False   False   False     False  False    False
# 1      False                   True   False   False      True  False    False
# 2      False                  False   False   False      True  False    False
# 3      False                   True   False   False      True  False    False
# 4      False                  False   False   False      True  False    False
# ...      ...                    ...     ...     ...       ...    ...      ...
# 45461  False                   True   False   False     False  False    False
# 45462  False                   True   False   False      True  False    False
# 45463  False                   True   False   False      True  False    False
# 45464  False                   True   False   False      True  False    False
# 45465  False                   True   False   False      True  False    False
#
#        original_language  original_title  overview  ...  release_date  \
# 0                  False           False     False  ...         False
# 1                  False           False     False  ...         False
# 2                  False           False     False  ...         False
# 3                  False           False     False  ...         False
# 4                  False           False     False  ...         False
# ...                  ...             ...       ...  ...           ...
# 45461              False           False     False  ...          True
# 45462              False           False     False  ...         False
# 45463              False           False     False  ...         False
# 45464              False           False     False  ...         False
# 45465              False           False     False  ...         False
#
#        revenue  runtime  spoken_languages  status  tagline  title  video  \
# 0        False    False             False   False     True  False  False
# 1        False    False             False   False    False  False  False
# 2        False    False             False   False    False  False  False
# 3        False    False             False   False    False  False  False
# 4        False    False             False   False    False  False  False
# ...        ...      ...               ...     ...      ...    ...    ...
# 45461    False    False             False   False    False  False  False
# 45462    False    False             False   False     True  False  False
# 45463    False    False             False   False    False  False  False
# 45464    False    False             False   False     True  False  False
# 45465    False    False             False   False     True  False  False
#
#        vote_average  vote_count
# 0             False       False
# 1             False       False
# 2             False       False
# 3             False       False
# 4             False       False
# ...             ...         ...
# 45461         False       False
# 45462         False       False
# 45463         False       False
# 45464         False       False
# 45465         False       False
#
# [45466 rows x 24 columns]

# %% [markdown]
# ### g) Count unique values in each attribute of the data frame

# %%
ds.nunique()
# Out:
# adult                        5
# belongs_to_collection     1698
# budget                    1226
# genres                    4069
# homepage                  7673
# id                       45436
# imdb_id                  45417
# original_language           92
# original_title           43373
# overview                 44307
# popularity               44176
# poster_path              45024
# production_companies     22708
# production_countries      2393
# release_date             17336
# revenue                   6863
# runtime                    353
# spoken_languages          1931
# status                       6
# tagline                  20283
# title                    42277
# video                        2
# vote_average                92
# vote_count                1820
# dtype: int64

# %%
ds.budget.unique()
# Out:
# array(['30000000', '65000000', '0', ..., '3417000', '25868826', '1254040'],
#       dtype=object)

# %% [markdown]
# ### h) Count each unique values in the status attribute

# %%
ds.status.value_counts()
# Out:
# Released           45014
# Rumored              230
# Post Production       98
# In Production         20
# Planned               15
# Canceled               2
# Name: status, dtype: int64

# %% [markdown]
# ### i) Get the columnds of data frame

# %%
ds.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'video', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %% [markdown]
# ### j) Get the information of the data frame

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45466 entries, Toy Story to Queerama
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
#  14  release_date           45379 non-null  object
#  15  revenue                45460 non-null  float64
#  16  runtime                45203 non-null  float64
#  17  spoken_languages       45460 non-null  object
#  18  status                 45379 non-null  object
#  19  tagline                20412 non-null  object
#  20  video                  45460 non-null  object
#  21  vote_average           45460 non-null  float64
#  22  vote_count             45460 non-null  float64
# dtypes: float64(4), object(19)
# memory usage: 9.3+ MB

# %% [markdown]
# ### k) Get the details of the third movie of the dataframe

# %%
ds.iloc[2]
# Out:
# adult                                                                False
# belongs_to_collection    {'id': 119050, 'name': 'Grumpy Old Men Collect...
# budget                                                                   0
# genres                   [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# homepage                                                               NaN
# id                                                                   15602
# imdb_id                                                          tt0113228
# original_language                                                       en
# original_title                                            Grumpier Old Men
# overview                 A family wedding reignites the ancient feud be...
# popularity                                                         11.7129
# poster_path                               /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg
# production_companies     [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# production_countries     [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                    1995-12-22
# revenue                                                                0.0
# runtime                                                              101.0
# spoken_languages                  [{'iso_639_1': 'en', 'name': 'English'}]
# status                                                            Released
# tagline                  Still Yelling. Still Fighting. Still Ready for...
# video                                                                False
# vote_average                                                           6.5
# vote_count                                                            92.0
# Name: Grumpier Old Men, dtype: object

# %% [markdown]
# ### l) Count the numbers of rows and  columns of the data frame

# %%
ds.shape
# Out:
# (45466, 24)

# %% [markdown]
# ### m) Get the details of the columns title and genres of the data

# %%
ds[['title','genres']]
# Out:
#                              title  \
# 0                        Toy Story
# 1                          Jumanji
# 2                 Grumpier Old Men
# 3                Waiting to Exhale
# 4      Father of the Bride Part II
# ...                            ...
# 45461                       Subdue
# 45462          Century of Birthing
# 45463                     Betrayal
# 45464             Satan Triumphant
# 45465                     Queerama
#
#                                                   genres
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                         [{'id': 35, 'name': 'Comedy'}]
# ...                                                  ...
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                      [{'id': 18, 'name': 'Drama'}]
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                 []
# 45465                                                 []
#
# [45466 rows x 2 columns]

# %% [markdown]
# ### n) Get the details of the movie with the title 'Grumpier Old Men'

# %%
ds.loc['Grumpier Old Men']
# Out:
# adult                                                                False
# belongs_to_collection    {'id': 119050, 'name': 'Grumpy Old Men Collect...
# budget                                                                   0
# genres                   [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# homepage                                                               NaN
# id                                                                   15602
# imdb_id                                                          tt0113228
# original_language                                                       en
# original_title                                            Grumpier Old Men
# overview                 A family wedding reignites the ancient feud be...
# popularity                                                         11.7129
# poster_path                               /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg
# production_companies     [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# production_countries     [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                    1995-12-22
# revenue                                                                0.0
# runtime                                                              101.0
# spoken_languages                  [{'iso_639_1': 'en', 'name': 'English'}]
# status                                                            Released
# tagline                  Still Yelling. Still Fighting. Still Ready for...
# video                                                                False
# vote_average                                                           6.5
# vote_count                                                            92.0
# Name: Grumpier Old Men, dtype: object

# %% [markdown]
# ### o) create a smaller data frame with a subset of all features

# %%
ds[['release_date','budget','revenue','runtime']]
# Out:
#                             release_date    budget      revenue  runtime
# title
# Toy Story                     1995-10-30  30000000  373554033.0     81.0
# Jumanji                       1995-12-15  65000000  262797249.0    104.0
# Grumpier Old Men              1995-12-22         0          0.0    101.0
# Waiting to Exhale             1995-12-22  16000000   81452156.0    127.0
# Father of the Bride Part II   1995-02-10         0   76578911.0    106.0
# ...                                  ...       ...          ...      ...
# Subdue                               NaN         0          0.0     90.0
# Century of Birthing           2011-11-17         0          0.0    360.0
# Betrayal                      2003-08-01         0          0.0     90.0
# Satan Triumphant              1917-10-21         0          0.0     87.0
# Queerama                      2017-06-09         0          0.0     75.0
#
# [45466 rows x 4 columns]

# %% [markdown]
# ### p) sort the data frame based on a release _date

# %%
ds.sort_values('release_date')
# Out:
#                                                                                             adult  \
# title
# NaN                                                                            - Written by Ørnås
# NaN                                              Rune Balot goes to a casino connected to the ...
# Passage of Venus                                                                            False
# Sallie Gardner at a Gallop                                                                  False
# Buffalo Running                                                                             False
# ...                                                                                           ...
# Engineering Red                                                                             False
# All Superheroes Must Die 2: The Last Superhero                                              False
# The Land Where the Blues Began                                                              False
# Aprel                                                                                       False
# Subdue                                                                                      False
#
#                                                belongs_to_collection  \
# title
# NaN                                                         0.065736
# NaN                                                         1.931659
# Passage of Venus                                                 NaN
# Sallie Gardner at a Gallop                                       NaN
# Buffalo Running                                                  NaN
# ...                                                              ...
# Engineering Red                                                  NaN
# All Superheroes Must Die 2: The Last Superhero                   NaN
# The Land Where the Blues Began                                   NaN
# Aprel                                                            NaN
# Subdue                                                           NaN
#
#                                                                           budget  \
# title
# NaN                                             /ff9qCepilowshEtG2GYWwzt2bs4.jpg
# NaN                                             /zV8bHuSL6WXoD6FWogP9j4x80bL.jpg
# Passage of Venus                                                               0
# Sallie Gardner at a Gallop                                                     0
# Buffalo Running                                                                0
# ...                                                                          ...
# Engineering Red                                                                0
# All Superheroes Must Die 2: The Last Superhero                                 0
# The Land Where the Blues Began                                                 0
# Aprel                                                                          0
# Subdue                                                                         0
#
#                                                                                            genres  \
# title
# NaN                                             [{'name': 'Carousel Productions', 'id': 11176}...
# NaN                                             [{'name': 'Aniplex', 'id': 2883}, {'name': 'Go...
# Passage of Venus                                              [{'id': 99, 'name': 'Documentary'}]
# Sallie Gardner at a Gallop                                    [{'id': 99, 'name': 'Documentary'}]
# Buffalo Running                                               [{'id': 99, 'name': 'Documentary'}]
# ...                                                                                           ...
# Engineering Red                                                                                []
# All Superheroes Must Die 2: The Last Superhero  [{'id': 9648, 'name': 'Mystery'}, {'id': 878, ...
# The Land Where the Blues Began                                                                 []
# Aprel                                           [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# Subdue                                          [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
#
#                                                                                          homepage  \
# title
# NaN                                             [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...
# NaN                                             [{'iso_3166_1': 'US', 'name': 'United States o...
# Passage of Venus                                                                              NaN
# Sallie Gardner at a Gallop                                                                    NaN
# Buffalo Running                                                                               NaN
# ...                                                                                           ...
# Engineering Red                                                                               NaN
# All Superheroes Must Die 2: The Last Superhero                                                NaN
# The Land Where the Blues Began                                                                NaN
# Aprel                                                                                         NaN
# Subdue                                                       http://www.imdb.com/title/tt6209470/
#
#                                                         id    imdb_id  \
# title
# NaN                                             1997-08-20          0
# NaN                                             2012-09-29          0
# Passage of Venus                                    315946  tt3155794
# Sallie Gardner at a Gallop                          194079  tt2221420
# Buffalo Running                                     426903  tt5459794
# ...                                                    ...        ...
# Engineering Red                                     438910  tt0810384
# All Superheroes Must Die 2: The Last Superhero      433711  tt3158690
# The Land Where the Blues Began                      335251  tt1883368
# Aprel                                               449131  tt0321264
# Subdue                                              439050  tt6209470
#
#                                                original_language  \
# title
# NaN                                                        104.0
# NaN                                                         68.0
# Passage of Venus                                              xx
# Sallie Gardner at a Gallop                                    en
# Buffalo Running                                               en
# ...                                                          ...
# Engineering Red                                               ru
# All Superheroes Must Die 2: The Last Superhero                en
# The Land Where the Blues Began                                en
# Aprel                                                         ru
# Subdue                                                        fa
#
#                                                                                 original_title  \
# title
# NaN                                                   [{'iso_639_1': 'en', 'name': 'English'}]
# NaN                                                       [{'iso_639_1': 'ja', 'name': '日本語'}]
# Passage of Venus                                                              Passage de Venus
# Sallie Gardner at a Gallop                                          Sallie Gardner at a Gallop
# Buffalo Running                                                                Buffalo Running
# ...                                                                                        ...
# Engineering Red                                              Konstruktor krasnogo tsveta -1993
# All Superheroes Must Die 2: The Last Superhero  All Superheroes Must Die 2: The Last Superhero
# The Land Where the Blues Began                                  The Land Where the Blues Began
# Aprel                                                                                    Aprel
# Subdue                                                                                 رگ خواب
#
#                                                                                          overview  \
# title
# NaN                                                                                      Released
# NaN                                                                                      Released
# Passage of Venus                                Photo sequence of the rare transit of Venus ov...
# Sallie Gardner at a Gallop                      Sallie Gardner at a Gallop was one of the earl...
# Buffalo Running                                 Individual photographs of the running of a buf...
# ...                                                                                           ...
# Engineering Red                                 Engineering Red - 1993  Dir: Andrey I. Y. Petr...
# All Superheroes Must Die 2: The Last Superhero  In a no holds barred documentary, acclaimed jo...
# The Land Where the Blues Began                  An exploration of the musical and social origi...
# Aprel                                                                                         NaN
# Subdue                                                Rising and falling between a man and woman.
#
#                                                 ...  \
# title                                           ...
# NaN                                             ...
# NaN                                             ...
# Passage of Venus                                ...
# Sallie Gardner at a Gallop                      ...
# Buffalo Running                                 ...
# ...                                             ...
# Engineering Red                                 ...
# All Superheroes Must Die 2: The Last Superhero  ...
# The Land Where the Blues Began                  ...
# Aprel                                           ...
# Subdue                                          ...
#
#                                                                              production_countries  \
# title
# NaN                                                                                           6.0
# NaN                                                                                           7.0
# Passage of Venus                                         [{'iso_3166_1': 'FR', 'name': 'France'}]
# Sallie Gardner at a Gallop                      [{'iso_3166_1': 'US', 'name': 'United States o...
# Buffalo Running                                 [{'iso_3166_1': 'US', 'name': 'United States o...
# ...                                                                                           ...
# Engineering Red                                                                                []
# All Superheroes Must Die 2: The Last Superhero                                                 []
# The Land Where the Blues Began                                                                 []
# Aprel                                                    [{'iso_3166_1': 'RU', 'name': 'Russia'}]
# Subdue                                                     [{'iso_3166_1': 'IR', 'name': 'Iran'}]
#
#                                                release_date revenue runtime  \
# title
# NaN                                                       1     NaN     NaN
# NaN                                                      12     NaN     NaN
# Passage of Venus                                 1874-12-09     0.0     1.0
# Sallie Gardner at a Gallop                       1878-06-14     0.0     1.0
# Buffalo Running                                  1883-11-19     0.0     1.0
# ...                                                     ...     ...     ...
# Engineering Red                                         NaN     0.0    76.0
# All Superheroes Must Die 2: The Last Superhero          NaN     0.0    74.0
# The Land Where the Blues Began                          NaN     0.0     0.0
# Aprel                                                   NaN     0.0     NaN
# Subdue                                                  NaN     0.0    90.0
#
#                                                                             spoken_languages  \
# title
# NaN                                                                                      NaN
# NaN                                                                                      NaN
# Passage of Venus                                [{'iso_639_1': 'xx', 'name': 'No Language'}]
# Sallie Gardner at a Gallop                      [{'iso_639_1': 'xx', 'name': 'No Language'}]
# Buffalo Running                                 [{'iso_639_1': 'xx', 'name': 'No Language'}]
# ...                                                                                      ...
# Engineering Red                                                                           []
# All Superheroes Must Die 2: The Last Superhero      [{'iso_639_1': 'en', 'name': 'English'}]
# The Land Where the Blues Began                                                            []
# Aprel                                                                                     []
# Subdue                                                [{'iso_639_1': 'fa', 'name': 'فارسی'}]
#
#                                                   status  \
# title
# NaN                                                  NaN
# NaN                                                  NaN
# Passage of Venus                                Released
# Sallie Gardner at a Gallop                      Released
# Buffalo Running                                 Released
# ...                                                  ...
# Engineering Red                                 Released
# All Superheroes Must Die 2: The Last Superhero  Released
# The Land Where the Blues Began                  Released
# Aprel                                           Released
# Subdue                                          Released
#
#                                                                                    tagline  \
# title
# NaN                                                                                    NaN
# NaN                                                                                    NaN
# Passage of Venus                                                                       NaN
# Sallie Gardner at a Gallop                                                             NaN
# Buffalo Running                                                                        NaN
# ...                                                                                    ...
# Engineering Red                                                                        NaN
# All Superheroes Must Die 2: The Last Superhero                                         NaN
# The Land Where the Blues Began                                                         NaN
# Aprel                                                                                  NaN
# Subdue                                          Rising and falling between a man and woman
#
#                                                 video vote_average vote_count
# title
# NaN                                               NaN          NaN        NaN
# NaN                                               NaN          NaN        NaN
# Passage of Venus                                False          6.0       19.0
# Sallie Gardner at a Gallop                      False          6.2       25.0
# Buffalo Running                                 False          5.4        7.0
# ...                                               ...          ...        ...
# Engineering Red                                 False          6.0        2.0
# All Superheroes Must Die 2: The Last Superhero  False          4.0        1.0
# The Land Where the Blues Began                  False          0.0        0.0
# Aprel                                           False          6.0        1.0
# Subdue                                          False          4.0        1.0
#
# [45466 rows x 23 columns]

# %% [markdown]
# ### q) access those movies , released after 1995-01-01

# %%
ds[ds['release_date']>'19195-01-01']
# Out:
#                              adult  \
# title
# Toy Story                    False
# Jumanji                      False
# Grumpier Old Men             False
# Waiting to Exhale            False
# Father of the Bride Part II  False
# ...                            ...
# Caged Heat 3000              False
# Robin Hood                   False
# Century of Birthing          False
# Betrayal                     False
# Queerama                     False
#
#                                                          belongs_to_collection  \
# title
# Toy Story                    {'id': 10194, 'name': 'Toy Story Collection', ...
# Jumanji                                                                    NaN
# Grumpier Old Men             {'id': 119050, 'name': 'Grumpy Old Men Collect...
# Waiting to Exhale                                                          NaN
# Father of the Bride Part II  {'id': 96871, 'name': 'Father of the Bride Col...
# ...                                                                        ...
# Caged Heat 3000                                                            NaN
# Robin Hood                                                                 NaN
# Century of Birthing                                                        NaN
# Betrayal                                                                   NaN
# Queerama                                                                   NaN
#
#                                budget  \
# title
# Toy Story                    30000000
# Jumanji                      65000000
# Grumpier Old Men                    0
# Waiting to Exhale            16000000
# Father of the Bride Part II         0
# ...                               ...
# Caged Heat 3000                     0
# Robin Hood                          0
# Century of Birthing                 0
# Betrayal                            0
# Queerama                            0
#
#                                                                         genres  \
# title
# Toy Story                    [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# Jumanji                      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# Grumpier Old Men             [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# Waiting to Exhale            [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# Father of the Bride Part II                     [{'id': 35, 'name': 'Comedy'}]
# ...                                                                        ...
# Caged Heat 3000                       [{'id': 878, 'name': 'Science Fiction'}]
# Robin Hood                   [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# Century of Birthing                              [{'id': 18, 'name': 'Drama'}]
# Betrayal                     [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# Queerama                                                                    []
#
#                                                          homepage      id  \
# title
# Toy Story                    http://toystory.disney.com/toy-story     862
# Jumanji                                                       NaN    8844
# Grumpier Old Men                                              NaN   15602
# Waiting to Exhale                                             NaN   31357
# Father of the Bride Part II                                   NaN   11862
# ...                                                           ...     ...
# Caged Heat 3000                                               NaN  222848
# Robin Hood                                                    NaN   30840
# Century of Birthing                                           NaN  111109
# Betrayal                                                      NaN   67758
# Queerama                                                      NaN  461257
#
#                                imdb_id original_language  \
# title
# Toy Story                    tt0114709                en
# Jumanji                      tt0113497                en
# Grumpier Old Men             tt0113228                en
# Waiting to Exhale            tt0114885                en
# Father of the Bride Part II  tt0113041                en
# ...                                ...               ...
# Caged Heat 3000              tt0112613                en
# Robin Hood                   tt0102797                en
# Century of Birthing          tt2028550                tl
# Betrayal                     tt0303758                en
# Queerama                     tt6980792                en
#
#                                           original_title  \
# title
# Toy Story                                      Toy Story
# Jumanji                                          Jumanji
# Grumpier Old Men                        Grumpier Old Men
# Waiting to Exhale                      Waiting to Exhale
# Father of the Bride Part II  Father of the Bride Part II
# ...                                                  ...
# Caged Heat 3000                          Caged Heat 3000
# Robin Hood                                    Robin Hood
# Century of Birthing                  Siglo ng Pagluluwal
# Betrayal                                        Betrayal
# Queerama                                        Queerama
#
#                                                                       overview  \
# title
# Toy Story                    Led by Woody, Andy's toys live happily in his ...
# Jumanji                      When siblings Judy and Peter discover an encha...
# Grumpier Old Men             A family wedding reignites the ancient feud be...
# Waiting to Exhale            Cheated on, mistreated and stepped on, the wom...
# Father of the Bride Part II  Just when George Banks has recovered from his ...
# ...                                                                        ...
# Caged Heat 3000              It's the year 3000 AD. The world's most danger...
# Robin Hood                   Yet another version of the classic epic, with ...
# Century of Birthing          An artist struggles to finish his work while a...
# Betrayal                     When one of her hits goes wrong, a professiona...
# Queerama                     50 years after decriminalisation of homosexual...
#
#                              ...  \
# title                        ...
# Toy Story                    ...
# Jumanji                      ...
# Grumpier Old Men             ...
# Waiting to Exhale            ...
# Father of the Bride Part II  ...
# ...                          ...
# Caged Heat 3000              ...
# Robin Hood                   ...
# Century of Birthing          ...
# Betrayal                     ...
# Queerama                     ...
#
#                                                           production_countries  \
# title
# Toy Story                    [{'iso_3166_1': 'US', 'name': 'United States o...
# Jumanji                      [{'iso_3166_1': 'US', 'name': 'United States o...
# Grumpier Old Men             [{'iso_3166_1': 'US', 'name': 'United States o...
# Waiting to Exhale            [{'iso_3166_1': 'US', 'name': 'United States o...
# Father of the Bride Part II  [{'iso_3166_1': 'US', 'name': 'United States o...
# ...                                                                        ...
# Caged Heat 3000              [{'iso_3166_1': 'US', 'name': 'United States o...
# Robin Hood                   [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...
# Century of Birthing              [{'iso_3166_1': 'PH', 'name': 'Philippines'}]
# Betrayal                     [{'iso_3166_1': 'US', 'name': 'United States o...
# Queerama                      [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]
#
#                             release_date      revenue runtime  \
# title
# Toy Story                     1995-10-30  373554033.0    81.0
# Jumanji                       1995-12-15  262797249.0   104.0
# Grumpier Old Men              1995-12-22          0.0   101.0
# Waiting to Exhale             1995-12-22   81452156.0   127.0
# Father of the Bride Part II   1995-02-10   76578911.0   106.0
# ...                                  ...          ...     ...
# Caged Heat 3000               1995-01-01          0.0    85.0
# Robin Hood                    1991-05-13          0.0   104.0
# Century of Birthing           2011-11-17          0.0   360.0
# Betrayal                      2003-08-01          0.0    90.0
# Queerama                      2017-06-09          0.0    75.0
#
#                                                               spoken_languages  \
# title
# Toy Story                             [{'iso_639_1': 'en', 'name': 'English'}]
# Jumanji                      [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# Grumpier Old Men                      [{'iso_639_1': 'en', 'name': 'English'}]
# Waiting to Exhale                     [{'iso_639_1': 'en', 'name': 'English'}]
# Father of the Bride Part II           [{'iso_639_1': 'en', 'name': 'English'}]
# ...                                                                        ...
# Caged Heat 3000                       [{'iso_639_1': 'en', 'name': 'English'}]
# Robin Hood                            [{'iso_639_1': 'en', 'name': 'English'}]
# Century of Birthing                          [{'iso_639_1': 'tl', 'name': ''}]
# Betrayal                              [{'iso_639_1': 'en', 'name': 'English'}]
# Queerama                              [{'iso_639_1': 'en', 'name': 'English'}]
#
#                                status  \
# title
# Toy Story                    Released
# Jumanji                      Released
# Grumpier Old Men             Released
# Waiting to Exhale            Released
# Father of the Bride Part II  Released
# ...                               ...
# Caged Heat 3000              Released
# Robin Hood                   Released
# Century of Birthing          Released
# Betrayal                     Released
# Queerama                     Released
#
#                                                                        tagline  \
# title
# Toy Story                                                                  NaN
# Jumanji                              Roll the dice and unleash the excitement!
# Grumpier Old Men             Still Yelling. Still Fighting. Still Ready for...
# Waiting to Exhale            Friends are the people who let you be yourself...
# Father of the Bride Part II  Just When His World Is Back To Normal... He's ...
# ...                                                                        ...
# Caged Heat 3000                                                            NaN
# Robin Hood                                                                 NaN
# Century of Birthing                                                        NaN
# Betrayal                                                A deadly game of wits.
# Queerama                                                                   NaN
#
#                              video vote_average vote_count
# title
# Toy Story                    False          7.7     5415.0
# Jumanji                      False          6.9     2413.0
# Grumpier Old Men             False          6.5       92.0
# Waiting to Exhale            False          6.1       34.0
# Father of the Bride Part II  False          5.7      173.0
# ...                            ...          ...        ...
# Caged Heat 3000              False          3.5        1.0
# Robin Hood                   False          5.7       26.0
# Century of Birthing          False          9.0        3.0
# Betrayal                     False          3.8        6.0
# Queerama                     False          0.0        0.0
#
# [45033 rows x 23 columns]

# %% [markdown]
# ### r) sort movies on runtime in descending order

# %%
ds.sort_values('runtime',ascending=False)
# Out:
#                                 adult belongs_to_collection budget  \
# title
# Centennial                      False                   NaN      0
# Baseball                        False                   NaN      0
# Jazz                            False                   NaN      0
# Berlin Alexanderplatz           False                   NaN      0
# Heimat: A Chronicle of Germany  False                   NaN      0
# ...                               ...                   ...    ...
# Villa Henriette                 False                   NaN      0
# Między nami dobrze jest         False                   NaN      0
# Ostatni dzwonek                 False                   NaN      0
# Simbad e il califfo di Bagdad   False                   NaN      0
# Aprel                           False                   NaN      0
#
#                                                                            genres  \
# title
# Centennial                      [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# Baseball                                      [{'id': 99, 'name': 'Documentary'}]
# Jazz                                          [{'id': 99, 'name': 'Documentary'}]
# Berlin Alexanderplatz                               [{'id': 18, 'name': 'Drama'}]
# Heimat: A Chronicle of Germany  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# ...                                                                           ...
# Villa Henriette                                    [{'id': 35, 'name': 'Comedy'}]
# Między nami dobrze jest                                                        []
# Ostatni dzwonek                                     [{'id': 18, 'name': 'Drama'}]
# Simbad e il califfo di Bagdad                   [{'id': 12, 'name': 'Adventure'}]
# Aprel                           [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
#
#                                homepage      id    imdb_id original_language  \
# title
# Centennial                          NaN   67493  tt0076993                en
# Baseball                            NaN  126820  tt0108700                en
# Jazz                                NaN  142051  tt0221300                en
# Berlin Alexanderplatz               NaN   45560  tt0080196                de
# Heimat: A Chronicle of Germany      NaN   67463  tt0087400                de
# ...                                 ...     ...        ...               ...
# Villa Henriette                     NaN  231216  tt0441908                de
# Między nami dobrze jest             NaN  418757  tt4112020                pl
# Ostatni dzwonek                     NaN  369444  tt0098035                pl
# Simbad e il califfo di Bagdad       NaN  317389  tt0070695                es
# Aprel                               NaN  449131  tt0321264                ru
#
#                                                original_title  \
# title
# Centennial                                         Centennial
# Baseball                                             Baseball
# Jazz                                                     Jazz
# Berlin Alexanderplatz                   Berlin Alexanderplatz
# Heimat: A Chronicle of Germany  Heimat: Eine deutsche Chronik
# ...                                                       ...
# Villa Henriette                               Villa Henriette
# Między nami dobrze jest               Między nami dobrze jest
# Ostatni dzwonek                               Ostatni dzwonek
# Simbad e il califfo di Bagdad   Simbad e il califfo di Bagdad
# Aprel                                                   Aprel
#
#                                                                          overview  \
# title
# Centennial                      The economic and cultural growth of Colorado s...
# Baseball                        Chronicles the sport's signature people, place...
# Jazz                            A survey of the musical form's history and maj...
# Berlin Alexanderplatz           Berlin Alexanderplatz, originally broadcast in...
# Heimat: A Chronicle of Germany  This epic tale of a family and their rural lif...
# ...                                                                           ...
# Villa Henriette                                                               NaN
# Między nami dobrze jest                                                       NaN
# Ostatni dzwonek                                                               NaN
# Simbad e il califfo di Bagdad                                                 NaN
# Aprel                                                                         NaN
#
#                                 ...  \
# title                           ...
# Centennial                      ...
# Baseball                        ...
# Jazz                            ...
# Berlin Alexanderplatz           ...
# Heimat: A Chronicle of Germany  ...
# ...                             ...
# Villa Henriette                 ...
# Między nami dobrze jest         ...
# Ostatni dzwonek                 ...
# Simbad e il califfo di Bagdad   ...
# Aprel                           ...
#
#                                                              production_countries  \
# title
# Centennial                      [{'iso_3166_1': 'US', 'name': 'United States o...
# Baseball                                                                       []
# Jazz                                                                           []
# Berlin Alexanderplatz           [{'iso_3166_1': 'DE', 'name': 'Germany'}, {'is...
# Heimat: A Chronicle of Germany          [{'iso_3166_1': 'DE', 'name': 'Germany'}]
# ...                                                                           ...
# Villa Henriette                 [{'iso_3166_1': 'AT', 'name': 'Austria'}, {'is...
# Między nami dobrze jest                                                        []
# Ostatni dzwonek                          [{'iso_3166_1': 'PL', 'name': 'Poland'}]
# Simbad e il califfo di Bagdad             [{'iso_3166_1': 'IT', 'name': 'Italy'}]
# Aprel                                    [{'iso_3166_1': 'RU', 'name': 'Russia'}]
#
#                                release_date revenue runtime  \
# title
# Centennial                       1978-10-01     0.0  1256.0
# Baseball                         1994-09-18     0.0  1140.0
# Jazz                             2001-01-09     0.0  1140.0
# Berlin Alexanderplatz            1980-08-28     0.0   931.0
# Heimat: A Chronicle of Germany   1984-09-16     0.0   925.0
# ...                                     ...     ...     ...
# Villa Henriette                  2004-12-02     0.0     NaN
# Między nami dobrze jest          2014-08-01     0.0     NaN
# Ostatni dzwonek                  1989-10-27     0.0     NaN
# Simbad e il califfo di Bagdad    1973-07-22     0.0     NaN
# Aprel                                   NaN     0.0     NaN
#
#                                                          spoken_languages  \
# title
# Centennial                                                             []
# Baseball                         [{'iso_639_1': 'en', 'name': 'English'}]
# Jazz                                                                   []
# Berlin Alexanderplatz            [{'iso_639_1': 'de', 'name': 'Deutsch'}]
# Heimat: A Chronicle of Germany                                         []
# ...                                                                   ...
# Villa Henriette                  [{'iso_639_1': 'de', 'name': 'Deutsch'}]
# Między nami dobrze jest                                                []
# Ostatni dzwonek                                                        []
# Simbad e il califfo di Bagdad   [{'iso_639_1': 'it', 'name': 'Italiano'}]
# Aprel                                                                  []
#
#                                   status  tagline  video vote_average  \
# title
# Centennial                      Released      NaN  False          7.9
# Baseball                        Released      NaN  False          8.5
# Jazz                            Released      NaN  False          5.7
# Berlin Alexanderplatz           Released      NaN  False          8.4
# Heimat: A Chronicle of Germany  Released      NaN  False          9.0
# ...                                  ...      ...    ...          ...
# Villa Henriette                 Released      NaN  False          0.0
# Między nami dobrze jest         Released      NaN  False          0.0
# Ostatni dzwonek                 Released      NaN  False          0.0
# Simbad e il califfo di Bagdad   Released      NaN  False          0.0
# Aprel                           Released      NaN  False          6.0
#
#                                vote_count
# title
# Centennial                            8.0
# Baseball                              4.0
# Jazz                                  3.0
# Berlin Alexanderplatz                 5.0
# Heimat: A Chronicle of Germany        1.0
# ...                                   ...
# Villa Henriette                       0.0
# Między nami dobrze jest               0.0
# Ostatni dzwonek                       0.0
# Simbad e il califfo di Bagdad         0.0
# Aprel                                 1.0
#
# [45466 rows x 23 columns]

# %% [markdown]
# ### t) get the longest runtime & shortest runtime

# %%
ds[['runtime']]
# Out:
#                              runtime
# title
# Toy Story                       81.0
# Jumanji                        104.0
# Grumpier Old Men               101.0
# Waiting to Exhale              127.0
# Father of the Bride Part II    106.0
# ...                              ...
# Subdue                          90.0
# Century of Birthing            360.0
# Betrayal                        90.0
# Satan Triumphant                87.0
# Queerama                        75.0
#
# [45466 rows x 1 columns]

# %% [markdown]
# ### u) calculate the number of votes garnered by the 70% movie

# %%
ds['vote_count'].quantile(0.70)
# Out:
# 25.0

# %% [markdown]
# ### v) display the movies (title,runtime) longer than 30 minutes & shorter than 360 minutes

# %%
ds[(ds['runtime']>=30)& (ds['runtime']<=360)][['release_date','budget','revenue','runtime']]
# Out:
#                             release_date    budget      revenue  runtime
# title
# Toy Story                     1995-10-30  30000000  373554033.0     81.0
# Jumanji                       1995-12-15  65000000  262797249.0    104.0
# Grumpier Old Men              1995-12-22         0          0.0    101.0
# Waiting to Exhale             1995-12-22  16000000   81452156.0    127.0
# Father of the Bride Part II   1995-02-10         0   76578911.0    106.0
# ...                                  ...       ...          ...      ...
# Subdue                               NaN         0          0.0     90.0
# Century of Birthing           2011-11-17         0          0.0    360.0
# Betrayal                      2003-08-01         0          0.0     90.0
# Satan Triumphant              1917-10-21         0          0.0     87.0
# Queerama                      2017-06-09         0          0.0     75.0
#
# [42297 rows x 4 columns]

# %% [markdown]
# ### w) display the movies (title , numer of votes) that received specified number of

# %%
ds[ds['vote_count']>500][['release_date','budget','revenue','runtime']]
# Out:
#                               release_date     budget      revenue  runtime
# title
# Toy Story                       1995-10-30   30000000  373554033.0     81.0
# Jumanji                         1995-12-15   65000000  262797249.0    104.0
# Heat                            1995-12-15   60000000  187436818.0    170.0
# GoldenEye                       1995-11-16   58000000  352194034.0    130.0
# Casino                          1995-11-22   52000000  116112375.0    178.0
# ...                                    ...        ...          ...      ...
# What Happened to Monday         2017-08-18          0          0.0    123.0
# Atomic Blonde                   2017-07-26   30000000   90007945.0    115.0
# Dunkirk                         2017-07-19  100000000  519876949.0    107.0
# Transformers: The Last Knight   2017-06-21  260000000  604942143.0    149.0
# The Dark Tower                  2017-08-03   60000000   71000000.0     95.0
#
# [2049 rows x 4 columns]
