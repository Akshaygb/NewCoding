# %% [markdown]
# # Assignment 3

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Read text file (old car dataset)

# %%
cols=['symboling','normalized-losses','make','fuel-type','aspiration','num-of-doors','body-style','drive-wheels','engines-location','wheel-base','length','width','height','crub-weight','engine-type','num-of-cylinders','engine-size','fuel-system','bore','stroke','compression-ratio','horsepower','peak-rpm','city-mpg','highway-mpg','price',]
ds=pd.read_csv('imports-85.data',names=cols)
ds
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engines-location  wheel-base  ...  \
# 0            two  convertible          rwd            front        88.6  ...
# ...

# %%
print(ds.shape)
ds.head()
# Out:
# (205, 26)
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engines-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd            front        88.6  ...          130
# 1  convertible          rwd            front        88.6  ...          130
# 2    hatchback          rwd            front        94.5  ...          152
# 3        sedan          fwd            front        99.8  ...          109
# 4        sedan          4wd            front        99.4  ...          136
#
# ...

# %% [markdown]
# ## Identify missing values, evaluate missing values, deal with missing values and correct data format

# %%
# Identify missing values
data=ds.replace("?",np.NaN)
data
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               NaN  alfa-romero       gas        std
# 1            3               NaN  alfa-romero       gas        std
# 2            1               NaN  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engines-location  wheel-base  ...  \
# 0            two  convertible          rwd            front        88.6  ...
# ...

# %%
# Evaluating missing values
ds.isnull().any().any()
# Out:
# False

# %%
ds.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engines-location     0
# wheel-base           0
# length               0
# width                0
# height               0
# crub-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
#Compute the mean of 'normalized-losses
avg_norm_loss1=data['normalized-losses'].astype("float").mean()
avg_norm_loss1
# Out:
# 122.0

# %%
#Replace missing values by mean
data['normalized-losses'].replace(np.NaN,avg_norm_loss1,inplace=True)
data['normalized-losses']
# Out:
# 0      122.0
# 1      122.0
# 2      122.0
# 3        164
# 4        164
#        ...
# 200       95
# 201       95
# 202       95
# 203       95
# 204       95
# Name: normalized-losses, Length: 205, dtype: object

# %%
data
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3             122.0  alfa-romero       gas        std
# 1            3             122.0  alfa-romero       gas        std
# 2            1             122.0  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engines-location  wheel-base  ...  \
# 0            two  convertible          rwd            front        88.6  ...
# ...

# %%
#Compute the mean of 'bore'
avg_bore=data['bore'].astype("float").mean()
avg_bore
# Out:
# 3.3297512437810957

# %%
data
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3             122.0  alfa-romero       gas        std
# 1            3             122.0  alfa-romero       gas        std
# 2            1             122.0  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engines-location  wheel-base  ...  \
# 0            two  convertible          rwd            front        88.6  ...
# ...

# %%
#Compute mean of the Stroke
avg_stroke=data['stroke'].astype("float").mean(axis=0)
avg_stroke
# Out:
# 3.2554228855721337

# %%
data['stroke'].replace(np.NaN,avg_norm_loss,inplace=True)
data['stroke']
# Out:
# 0      2.68
# 1      2.68
# 2      3.47
# 3      3.40
# 4      3.40
#        ...
# 200    3.15
# 201    3.15
# 202    2.87
# 203    3.40
# 204    3.15
# Name: stroke, Length: 205, dtype: object

# %%
#Get the total number of missing values now
data.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         2
# body-style           0
# drive-wheels         0
# engines-location     0
# wheel-base           0
# length               0
# width                0
# height               0
# crub-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 4
# stroke               0
# compression-ratio    0
# horsepower           2
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                4
# dtype: int64

# %%
# Datatype of 'bore'
data['bore'].dtype
# Out:
# dtype('O')

# %%
#Compute the mean of 'bore'
avg_horsepower=data['horsepower'].astype("float").mean(axis=0)
avg_horsepower
# Out:
# 104.25615763546799

# %%
#find average value of'horsepower'
data['horsepower'].replace(np.NaN,avg_norm_loss,inplace=True)
data['horsepower']
# Out:
# 0      111
# 1      111
# 2      154
# 3      102
# 4      115
#       ...
# 200    114
# 201    160
# 202    134
# 203    106
# 204    114
# Name: horsepower, Length: 205, dtype: object

# %%
#Find average value of 'peak-rpm'
avg_peakrpm=data['peak-rpm'].astype("float").mean(axis=0)
avg_peakrpm
# Out:
# 5125.369458128079

# %%
data['peak-rpm'].replace(np.NaN,avg_norm_loss,inplace=True)
data['peak-rpm']
# Out:
# 0      5000
# 1      5000
# 2      5000
# 3      5500
# 4      5500
#        ...
# 200    5400
# 201    5300
# 202    5500
# 203    4800
# 204    5400
# Name: peak-rpm, Length: 205, dtype: object

# %%
#Relacing the missing values present in num-of-doors
data['num-of-doors'].value_counts()
# Out:
# four    114
# two      89
# Name: num-of-doors, dtype: int64

# %%
#Getting the most frequesnt value
data['num-of-doors'].value_counts().idxmax()
# Out:
# 'four'

# %%
data['num-of-doors'].replace(np.NaN,'four',inplace=True)

# %%
data.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3             122.0  alfa-romero       gas        std          two
# 1          3             122.0  alfa-romero       gas        std          two
# 2          1             122.0  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engines-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd            front        88.6  ...          130
# 1  convertible          rwd            front        88.6  ...          130
# 2    hatchback          rwd            front        94.5  ...          152
# 3        sedan          fwd            front        99.8  ...          109
# 4        sedan          4wd            front        99.4  ...          136
#
# ...

# %%
#evaluating the missing values of 'price' attribute
before_rows=data.shape[0]
data.dropna(subset=['price'],axis=0,inplace=True)
after_rows=data.shape[0]
print("Number of dropped rows: {}".format(before_rows-after_rows))
#Reset index values
data.reset_index(drop=True,inplace=True)
# Out:
# Number of dropped rows: 4

# %%
#gETTING THE TOTAL NUMBER OF ROWS AND COLUMNS OF THE DATASET
data.shape
# Out:
# (201, 26)

# %%
#listing the datatypes of each attribute
data.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engines-location      object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# crub-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
#convert datatypes to proper format
data[['bore','stroke']]=data[['bore','stroke']].astype('float')
data[['normalized-losses']]=data[['normalized-losses']].astype('int')
data[['price']]=data[['price']].astype('float')
data[['peak-rpm']]=data[['peak-rpm']].astype('float')
data.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          3                122  alfa-romero       gas        std
# 2          1                122  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engines-location  wheel-base  ...  \
# 0          two  convertible          rwd            front        88.6  ...
# 1          two  convertible          rwd            front        88.6  ...
# 2          two    hatchback          rwd            front        94.5  ...
# 3         four        sedan          fwd            front        99.8  ...
# 4         four        sedan          4wd            front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %% [markdown]
# ## Data Standarzation

# %%
# transforming mpg to l/100km by mathematical operations 
data['highway-mpg']=235/data['highway-mpg']

# %%
#Rename the column name
data.rename(columns={'highway-mpg':'highway-L/100km'},inplace=True)
data.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          3                122  alfa-romero       gas        std
# 2          1                122  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engines-location  wheel-base  ...  \
# 0          two  convertible          rwd            front        88.6  ...
# 1          two  convertible          rwd            front        88.6  ...
# 2          two    hatchback          rwd            front        94.5  ...
# 3         four        sedan          fwd            front        99.8  ...
# 4         four        sedan          4wd            front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %% [markdown]
# ## Data Normalization (centring/scaling)

# %%
#normalization of the data
data['length']=data['length']/data['length'].max()
data['width']=data['width']/data['width'].max()
data['height']=data['height']/data['height'].max()
data.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          3                122  alfa-romero       gas        std
# 2          1                122  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engines-location  wheel-base  ...  \
# 0          two  convertible          rwd            front        88.6  ...
# 1          two  convertible          rwd            front        88.6  ...
# 2          two    hatchback          rwd            front        94.5  ...
# 3         four        sedan          fwd            front        99.8  ...
# 4         four        sedan          4wd            front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %% [markdown]
# ## Binning

# %%
#convert data to correct format
data['horsepower']=data['horsepower'].astype(int,copy=True)
data.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          3                122  alfa-romero       gas        std
# 2          1                122  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engines-location  wheel-base  ...  \
# 0          two  convertible          rwd            front        88.6  ...
# 1          two  convertible          rwd            front        88.6  ...
# 2          two    hatchback          rwd            front        94.5  ...
# 3         four        sedan          fwd            front        99.8  ...
# 4         four        sedan          4wd            front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
# Plot histogram with reespect to horsepower
# %matplotlib inline
import matplotlib.pyplot as plt
plt.hist(data['horsepower'],ec='black')
#plt.xlabel('horsepower')
#plt.ylabel('count')
plt.title("horsepower bins")
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %%
#binning
bins=np.linspace(min(data['horsepower']),max(data['horsepower']),4)
bins
# Out:
# array([ 48.        , 119.33333333, 190.66666667, 262.        ])

# %%
group_names=['low','medium','high']
data['horsepower-binned']=pd.cut(data['horsepower'],bins,labels=group_names,include_lowest=True)
data[['horsepower','horsepower-binned']].head(20)
# Out:
#     horsepower horsepower-binned
# 0          111               low
# 1          111               low
# 2          154            medium
# 3          102               low
# 4          115               low
# 5          110               low
# 6          110               low
# 7          110               low
# 8          140            medium
# 9          101               low
# 10         101               low
# 11         121            medium
# 12         121            medium
# 13         121            medium
# 14         182            medium
# 15         182            medium
# 16         182            medium
# 17          48               low
# 18          70               low
# 19          70               low

# %%
# total number of elements based on group name
data['horsepower-binned'].value_counts()
# Out:
# low       151
# medium     45
# high        5
# Name: horsepower-binned, dtype: int64

# %%
# ploting the bar graph
# %matplotlib inline
import matplotlib.pyplot as plt
plt.bar(group_names,data['horsepower-binned'].value_counts(),ec='black')
#plt.xlabel('horsepower')
#plt.ylabel('count')
plt.title("horsepower bins")
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %%
#bins visualization
# %matplotlib inline
import matplotlib.pyplot as plt
a=(0,1,2)
plt.hist(data['horsepower'],bins=3,ec='black')
#plt.xlabel('horsepower')
#plt.ylabel('count')
plt.title("horsepower bins")
plt.show()

# %% [markdown]
# ## Indicator variable

# %%
# Getting the indicator variables
dummy_variable_1=pd.get_dummies(data['fuel-type'])
dummy_variable_1.head()
# Out:
#    diesel  gas
# 0       0    1
# 1       0    1
# 2       0    1
# 3       0    1
# 4       0    1

# %%
# Rename the columns
dummy_variable_1.rename(columns={'fuel-type-gas':'gas','fuel-type-diesel':'disel'},inplace=True)
dummy_variable_1.head()
# Out:
#    diesel  gas
# 0       0    1
# 1       0    1
# 2       0    1
# 3       0    1
# 4       0    1

# %%
#Merge dataframe and dummy variables
data=pd.concat([data,dummy_variable_1],axis=1)

#drop original comulmn "fuel-type"
data.drop(columns='fuel-type',axis=1,inplace=True)
data.head()
# Out:
#    symboling normalized-losses         make aspiration num-of-doors  \
# 0          3             122.0  alfa-romero        std          two
# 1          3             122.0  alfa-romero        std          two
# 2          1             122.0  alfa-romero        std          two
# 3          2               164         audi        std         four
# 4          2               164         audi        std         four
#
#     body-style drive-wheels engines-location  wheel-base  length  ...  bore  \
# 0  convertible          rwd            front        88.6   168.8  ...  3.47
# 1  convertible          rwd            front        88.6   168.8  ...  3.47
# 2    hatchback          rwd            front        94.5   171.2  ...  2.68
# 3        sedan          fwd            front        99.8   176.6  ...  3.19
# 4        sedan          4wd            front        99.4   176.6  ...  3.19
#
#    stroke  compression-ratio horsepower peak-rpm  city-mpg highway-mpg  price  \
# ...

# %%
#second dummy variable
dummy_variable_2=pd.get_dummies(data['aspiration'])
dummy_variable_2.rename(columns={'std':'aspiration-std','turbo':'aspiration-turbo'},inplace=True)
dummy_variable_2.head()
# Out:
#    aspiration-std  aspiration-turbo
# 0               1                 0
# 1               1                 0
# 2               1                 0
# 3               1                 0
# 4               1                 0

# %%
#Merge dataframe and dummy variables
data=pd.concat([data,dummy_variable_2],axis=1)

#drop original comulmn "fuel-type"
data.drop(columns='aspiration',axis=1,inplace=True)
data.head()
# Out:
#    symboling normalized-losses         make num-of-doors   body-style  \
# 0          3             122.0  alfa-romero          two  convertible
# 1          3             122.0  alfa-romero          two  convertible
# 2          1             122.0  alfa-romero          two    hatchback
# 3          2               164         audi         four        sedan
# 4          2               164         audi         four        sedan
#
#   drive-wheels engines-location  wheel-base  length  width  ...  \
# 0          rwd            front        88.6   168.8   64.1  ...
# 1          rwd            front        88.6   168.8   64.1  ...
# 2          rwd            front        94.5   171.2   65.5  ...
# 3          fwd            front        99.8   176.6   66.2  ...
# 4          4wd            front        99.4   176.6   66.4  ...
#
#    compression-ratio  horsepower peak-rpm city-mpg  highway-mpg  price diesel  \
# ...

# %%
#print overall stastics of the dataset
data.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        crub-weight  engine-size  compression-ratio    city-mpg  highway-mpg  \
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %% [markdown]
# ## Writing csv file

# %%
new_data=data.to_csv('')

# %%
new_data

# %%
new=data.to_csv('file.csv')
new

# %%
#cols=['symboling','normalized-losses','make','fuel-type','aspiration','num-of-doors','body-style','drive-wheels','engines-location','wheel-base','length','width','height','crub-weight','engine-type','num-of-cylinders','engine-size','fuel-system','bore','stroke','compression-ratio','horsepower','peak-rpm','city-mpg','highway-mpg','price',]
ds=pd.read_csv('wrangled_data.csv')
ds
# Out:
#      Unnamed: 0  symboling  normalized-losses         make num-of-doors  \
# 0             0          3              122.0  alfa-romero          two
# 1             1          3              122.0  alfa-romero          two
# 2             2          1              122.0  alfa-romero          two
# 3             3          2              164.0         audi         four
# 4             4          2              164.0         audi         four
# ..          ...        ...                ...          ...          ...
# 200         200         -1               95.0        volvo         four
# 201         201         -1               95.0        volvo         four
# 202         202         -1               95.0        volvo         four
# 203         203         -1               95.0        volvo         four
# 204         204         -1               95.0        volvo         four
#
#       body-style drive-wheels engines-location  wheel-base  length  ...  \
# ...
