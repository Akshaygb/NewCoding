# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv('diamonds.csv')

# %%
dataset
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %%
dataset.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
dataset.tail()
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 53935  5.76  3.50
# 53936  5.75  3.61
# 53937  5.68  3.56
# 53938  6.12  3.74
# 53939  5.87  3.64

# %%
ds=dataset.drop(columns='Unnamed: 0',axis=1)
ds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
ds.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
ds.cut.unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
ds.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %%
ds.cut.nunique()
# Out:
# 5

# %%
ds.price.mean()
# Out:
# 3932.799721913237

# %%
ds.price.quantile(0.75)
# Out:
# 5324.25

# %%
ds.price.quantile(1)
# Out:
# 18823.0

# %%
ds.price.max()
# Out:
# 18823

# %%
q1=ds.price.quantile(0.25)

# %%
q1
# Out:
# 950.0

# %%
dataset=pd.read_csv('diamonds.csv').quantile(0.75)

# %%
dataset
# Out:
# Unnamed: 0    40455.25
# carat             1.04
# depth            62.50
# table            59.00
# price          5324.25
# x                 6.54
# y                 6.54
# z                 4.04
# Name: 0.75, dtype: float64

# %%
q2=ds.price.quantile(0.50)

# %%
q2
# Out:
# 2401.0

# %%
ds.price.hist()
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
plt.boxplot(ds['price'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2023e467490>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2023e467a30>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2023e4671c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2023e467fd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2023e46e2e0>],
#  'means': []}

# %%
import seaborn as sns
sns.countplot(x='price',ds)
# Out:
# C:\Users\91720\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price', ylabel='count'>

# %%
sns.countplot(x='price',data=ds)
# Out:
# <AxesSubplot:xlabel='price', ylabel='count'>

# %%
sns.countplot(x='cut',data=ds)
# Out:
# <AxesSubplot:xlabel='cut', ylabel='count'>

# %%
plt.scatter(data=ds,x='carat',y='price')

# %%
len(ds)
# Out:
# 53940

# %%
ds.query('x>y')
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z
# 1       0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 8       0.22     Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 11      0.23    Ideal     J     VS1   62.8   56.0    340  3.93  3.90  2.46
# 12      0.22  Premium     F     SI1   60.4   61.0    342  3.88  3.84  2.33
# 14      0.20  Premium     E     SI2   60.2   62.0    345  3.79  3.75  2.27
# ...      ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53928   0.79  Premium     E     SI2   61.4   58.0   2756  6.03  5.96  3.68
# 53929   0.71    Ideal     G     VS1   61.4   56.0   2756  5.76  5.73  3.53
# 53930   0.71  Premium     E     SI1   60.5   55.0   2756  5.79  5.74  3.49
# 53931   0.71  Premium     F     SI1   59.8   62.0   2756  5.74  5.73  3.43
# 53938   0.86  Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
#
# [23423 rows x 10 columns]

# %%
ds.cut.dtypes
# Out:
# dtype('O')

# %%
ds.dtypes
# Out:
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# price        int64
# x          float64
# y          float64
# z          float64
# dtype: object

# %%
ds.select_dtypes(include='int64')
# Out:
#        price
# 0        326
# 1        326
# 2        327
# 3        334
# 4        335
# ...      ...
# 53935   2757
# 53936   2757
# 53937   2757
# 53938   2757
# 53939   2757
#
# [53940 rows x 1 columns]

# %%
ds.select_dtypes(exclude=['int64','float64'])
# Out:
#              cut color clarity
# 0          Ideal     E     SI2
# 1        Premium     E     SI1
# 2           Good     E     VS1
# 3        Premium     I     VS2
# 4           Good     J     SI2
# ...          ...   ...     ...
# 53935      Ideal     D     SI1
# 53936       Good     D     SI1
# 53937  Very Good     D     SI1
# 53938    Premium     H     SI2
# 53939      Ideal     D     SI2
#
# [53940 rows x 3 columns]

# %%
ds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#        random_col
# 0              19
# ...

# %%
ds.drop(columns=['random_col1','random_col'],axis=1)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
random_col=np.random.randint(100,size=len(ds))
ds.insert(2,'random_col1',random_col1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [129], in <cell line: 2>()
#       1 random_col1=np.random.randint(100,size=len(ds))
# ----> 2 ds.insert(10,'random_col1',random_col1)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4440, in DataFrame.insert(self, loc, column, value, allow_duplicates)
#    4434     raise ValueError(
#    4435         "Cannot specify 'allow_duplicates=True' when "
#    4436         "'self.flags.allows_duplicate_labels' is False."
#    4437     )
#    4438 if not allow_duplicates and column in self.columns:
#    4439     # Should this be a different kind of error??
# -> 4440     raise ValueError(f"cannot insert {column}, already exists")
#    4441 if not isinstance(loc, int):
#    4442     raise TypeError("loc must be int")
#
# ValueError: cannot insert random_col1, already exists

# %%
ds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#        random_col1  random_col
# ...

# %%
ds=ds.drop(columns=['random_col1','random_col'],axis=1)

# %%
ds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
random_col=np.random.randint(100,size=len(ds))
ds.insert(2,'random_col1',random_col)

# %%
ds
# Out:
#        carat        cut  random_col1 color clarity  depth  table  price     x  \
# 0       0.23      Ideal           14     E     SI2   61.5   55.0    326  3.95
# 1       0.21    Premium           33     E     SI1   59.8   61.0    326  3.89
# 2       0.23       Good           19     E     VS1   56.9   65.0    327  4.05
# 3       0.29    Premium           79     I     VS2   62.4   58.0    334  4.20
# 4       0.31       Good           81     J     SI2   63.3   58.0    335  4.34
# ...      ...        ...          ...   ...     ...    ...    ...    ...   ...
# 53935   0.72      Ideal            9     D     SI1   60.8   57.0   2757  5.75
# 53936   0.72       Good           19     D     SI1   63.1   55.0   2757  5.69
# 53937   0.70  Very Good            0     D     SI1   62.8   60.0   2757  5.66
# 53938   0.86    Premium           86     H     SI2   61.0   58.0   2757  6.15
# 53939   0.75      Ideal           28     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# ...

# %%
ds[['price','x']].cumsum()
# Out:
#            price          x
# 0            326       3.95
# 1            652       7.84
# 2            979      11.89
# 3           1313      16.09
# 4           1648      20.43
# ...          ...        ...
# 53935  212124189  309115.29
# 53936  212126946  309120.98
# 53937  212129703  309126.64
# 53938  212132460  309132.79
# 53939  212135217  309138.62
#
# [53940 rows x 2 columns]

# %%
ds.sample(n=200)
# Out:
#        carat        cut  random_col1 color clarity  depth  table  price     x  \
# 14090   1.35    Premium           30     I     SI2   59.8   59.0   5715  7.26
# 18306   1.51  Very Good           21     I     SI2   60.6   60.2   7441  7.32
# 35072   0.38  Very Good           45     G     VS1   57.1   63.0    886  4.77
# 24462   1.50      Ideal           21     I      IF   61.3   56.0  12725  7.34
# 37625   0.44    Premium           29     G     SI1   61.6   61.0    990  4.88
# ...      ...        ...          ...   ...     ...    ...    ...    ...   ...
# 50587   0.74  Very Good           80     E     SI2   63.0   58.0   2282  5.73
# 17402   1.09      Ideal           92     H     SI1   61.4   56.0   6970  6.61
# 33675   0.32      Ideal            2     E    VVS2   60.9   55.0    837  4.41
# 14469   1.02      Ideal           98     E     SI1   62.2   54.7   5840  6.44
# 6226    1.02  Very Good           43     H     SI2   58.3   61.0   4004  6.57
#
#           y     z
# ...

# %%
ds.sample(frac=1)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 15672   1.04      Ideal     G     VS2   59.4   58.0   6286  6.63  6.67  3.95
# 37882   0.48    Premium     E     SI2   62.9   60.0   1005  4.93  4.90  3.09
# 42805   0.59      Ideal     J     VS2   60.8   57.0   1352  5.47  5.42  3.31
# 9907    1.00       Fair     F     SI1   56.9   63.0   4688  6.45  6.52  3.69
# 13168   1.00    Premium     E     SI1   62.6   60.0   5445  6.30  6.35  3.97
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 5775    1.18       Fair     D     SI2   57.0   66.0   3899  6.96  6.91  3.98
# 48718   0.56    Premium     D     VS2   61.5   58.0   2011  5.33  5.28  3.26
# 8510    1.03       Fair     G     SI1   64.7   63.0   4424  6.36  6.31  4.10
# 5947    0.74  Very Good     F    VVS2   61.5   55.1   3948  5.82  5.85  3.59
# 16381   1.32    Premium     F     SI2   60.6   60.0   6541  7.05  7.10  4.29
#
# [53940 rows x 10 columns]

# %%
ds['price'].where(ds['price']>200,0).head(50)
# Out:
# 0     326
# 1     326
# 2     327
# 3     334
# 4     335
# 5     336
# 6     336
# 7     337
# 8     337
# 9     338
# 10    339
# 11    340
# 12    342
# 13    344
# 14    345
# 15    345
# 16    348
# 17    351
# 18    351
# 19    351
# 20    351
# 21    352
# 22    353
# 23    353
# 24    353
# 25    354
# 26    355
# 27    357
# 28    357
# 29    357
# 30    402
# 31    402
# 32    402
# 33    402
# 34    402
# 35    402
# 36    402
# 37    402
# 38    403
# 39    403
# 40    403
# 41    403
# 42    403
# 43    403
# 44    403
# 45    403
# 46    403
# 47    403
# 48    404
# 49    404
# Name: price, dtype: int64

# %%
ds['rank_col']=ds['carat'].rank()
ds
# Out:
#        carat        cut  random_col1 color clarity  depth  table  price     x  \
# 0       0.23      Ideal           14     E     SI2   61.5   55.0    326  3.95
# 1       0.21    Premium           33     E     SI1   59.8   61.0    326  3.89
# 2       0.23       Good           19     E     VS1   56.9   65.0    327  4.05
# 3       0.29    Premium           79     I     VS2   62.4   58.0    334  4.20
# 4       0.31       Good           81     J     SI2   63.3   58.0    335  4.34
# ...      ...        ...          ...   ...     ...    ...    ...    ...   ...
# 53935   0.72      Ideal            9     D     SI1   60.8   57.0   2757  5.75
# 53936   0.72       Good           19     D     SI1   63.1   55.0   2757  5.69
# 53937   0.70  Very Good            0     D     SI1   62.8   60.0   2757  5.66
# 53938   0.86    Premium           86     H     SI2   61.0   58.0   2757  6.15
# 53939   0.75      Ideal           28     D     SI2   62.2   55.0   2757  5.83
#
#           y     z  rank_col
# ...

# %%
ds.replace('J','A').head(50)
# Out:
#     carat        cut color clarity  depth  table  price     x     y     z
# 0    0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1    0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2    0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3    0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4    0.31       Good     A     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5    0.24  Very Good     A    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6    0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7    0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8    0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9    0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39
# 10   0.30       Good     A     SI1   64.0   55.0    339  4.25  4.28  2.73
# 11   0.23      Ideal     A     VS1   62.8   56.0    340  3.93  3.90  2.46
# ...
